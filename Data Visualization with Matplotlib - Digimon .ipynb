# %% [markdown]
# <b>Data Visualization Lab -
#     What's Your Favorite Digimon? </b>
#
# Digimon, short for "digital monsters," is a franchise centered around the basic mechanics of capturing, nurturing, and training monsters to then engage in battles with them. It is similar to Pokémon. <br>
#
# This file contains a list of all Digimon in the game, including their level, shell, attribute, memory, and the number of equipment slots. All stats (HP, SP, attack, defense, intelligence, and speed) are for the Digimon at level 50.<br><br>
#
# For the rest of this exercise, you can use what we did during the course as a model (if you get lost). And for each question, feel free to write your observations/analyses! <br><br>
#
# 1 - Import the DigiDB_digimonlist.csv file and display the header.<br>
# 2 - Using the .info() function in pandas, check the column types and if any values are missing in some of them.<br>
# 3 - Using <b>Matplotlib</b>, display a bar chart of the number of Digimon by level (Stage).<br>
# 4 - Do the same exercise with attributes. There are more values...adjust the width of the chart to keep it simple to view.<br>
# 5 - Using <b>sns.distplot</b>, display the distribution of the Memory column.<br>
# 6 - Using <b>sns.kdeplot</b>, display only the distribution curve of the 'Lv 50 HP' column.<br>
# 7 - Using <b>Pandas' scatter_matrix</b>, display the distribution and scatter plots of the last 6 columns of the dataset.<br>
# 8 -There seems to be something interesting between 'Lv50 SP' and 'Lv50 Int'...use sns.jointplot to explore this in more detail.<br>
# 9 - Using <b>sns.lmplot</b>, add the Digimon level (Stage) to the scatter plot created in point 8.<br>
# 10 - Using <b>sns.violinplot</b>, visualize the distribution of 'Lv 50 HP' by Digimon stage.<br>

# %%
import pandas as pd
data = pd.read_csv('11 - DigiDB_digimonlist.csv', encoding='latin-1',sep=',')
data.head()
# Out:
#    Number  Digimon Stage  Type Attribute  Memory  Equip Slots  Lv 50 HP  \
# 0       1  Kuramon  Baby  Free   Neutral       2            0       590
# 1       2  Pabumon  Baby  Free   Neutral       2            0       950
# 2       3  Punimon  Baby  Free   Neutral       2            0       870
# 3       4  Botamon  Baby  Free   Neutral       2            0       690
# 4       5  Poyomon  Baby  Free   Neutral       2            0       540
#
#    Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# 0       77        79        69        68        95
# 1       62        76        76        69        68
# 2       50        97        87        50        75
# 3       68        77        95        76        61
# 4       98        54        59        95        86

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Number       249 non-null    int64
#  1   Digimon      249 non-null    object
#  2   Stage        249 non-null    object
#  3   Type         249 non-null    object
#  4   Attribute    249 non-null    object
#  5   Memory       249 non-null    int64
#  6   Equip Slots  249 non-null    int64
#  7   Lv 50 HP     249 non-null    int64
#  8   Lv50 SP      249 non-null    int64
#  9   Lv50 Atk     249 non-null    int64
#  10  Lv50 Def     249 non-null    int64
#  11  Lv50 Int     249 non-null    int64
#  12  Lv50 Spd     249 non-null    int64
# dtypes: int64(9), object(4)
# memory usage: 25.4+ KB

# %%
stages = data['Stage'].value_counts()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize = (7,5))
ax1 = fig.add_subplot(111)
ax1.bar(range(len(stages)),stages)
ax1.set_xticks(tick_positions)
ax1.set_xticklabels(stages.index, rotation= 45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 7
#       5 ax1 = fig.add_subplot(111)
#       6 ax1.bar(range(len(stages)),stages)
# ----> 7 ax1.set_xticks(tick_positions)
#       8 ax1.set_xticklabels(stages.index, rotation= 45)
#       9 plt.show()
#
# NameError: name 'tick_positions' is not defined

# %%
Type = data['Attribute'].value_counts() 

fig = plt.figure(figsize = (15,5))
ax1 = fig.add_subplot(111)
ax1.bar(range(len(Type)),Type)
tick_positions= range(0, len(Type))
ax1.set_xticks(tick_positions)
ax1.set_xticklabels(Types.index, rotation= 45)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 8
#       6 tick_positions= range(0, len(Type))
#       7 ax1.set_xticks(tick_positions)
# ----> 8 ax1.set_xticklabels(Types.index, rotation= 45)
#      10 plt.show()
#
# NameError: name 'Types' is not defined

# %%
import seaborn as sns
sns.distplot(data["Memory"])
sns.set()
plt.show()
# Out:
# /var/folders/st/vgtwy6fs58s8t1k60x9zb2dm0000gn/T/ipykernel_22615/2710654272.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Memory"])

# %%
sns.kdeplot(data["Lv 50 HP"], shade=True)
sns.set()
plt.xlabel("Lv 50 HP")
plt.show()
# Out:
# /var/folders/st/vgtwy6fs58s8t1k60x9zb2dm0000gn/T/ipykernel_22615/1123218514.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data["Lv 50 HP"], shade=True)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data[['Lv 50 HP','Lv50 SP', 'Lv50 Atk', 'Lv50 Def', 'Lv50 Int', 'Lv50 Spd']], figsize=(15,15))
plt.show()

# %%
sns.jointplot('Lv 50 SP', 'Lv50 Int', data=data, kind="reg")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 sns.jointplot('Lv 50 SP', 'Lv50 Int', data=data, kind="reg")
#       2 plt.show()
#
# TypeError: jointplot() got multiple values for argument 'data'

# %%
sns.lmplot(x='Lv50 SP', y='Lv50 Int', hue="Stage", data=data, fit_reg=False)
plt.show()
# Out:
# /Users/melaniedanet/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig, ax=plt.subplots()
fig.set_size_inches(12,8)
sns.violinplot(x="Stage", y="Lv 50 HP", data=data)
plt.show()
